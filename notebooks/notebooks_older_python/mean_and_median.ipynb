# %%
# %cd ../..
# Out:
# c:\Users\Stefo\Programming\Proper-Pandas

# %%
from testing_functions.operations_on_number_files import *
import utilities.benchmark as bench
from utilities.compare_benchmarks import compare_benchmarks, compare_statistics_benchmarks
from utilities.compare_dataframes import compare_dataframes

from config import ITERATION_COUNT

bench.ITERATIONS =ITERATION_COUNT

# %% [markdown]
# ## Use numpy to check whether better performance can be achieved for some basic functions like calculating mean and median values for rows and columns

# %%
SMALL = pd.read_csv('./test_files/small_number.csv')
MEDIUM = pd.read_csv('./test_files/medium_number.csv')
BIG = pd.read_csv('./test_files/big_number.csv')

# %%
mean_rows_small_number = bench.benchmark(
    mean_rows,
    SMALL
)
mean_rows_small_number_improved = bench.benchmark(
    mean_rows_improved,
    SMALL
)


mean_rows_medium_number = bench.benchmark(
    mean_rows,
    MEDIUM
)
mean_rows_medium_number_improved = bench.benchmark(
    mean_rows_improved,
    MEDIUM
)


mean_rows_big_number = bench.benchmark(
    mean_rows,
    BIG
)
mean_rows_big_number_improved = bench.benchmark(
    mean_rows_improved,
    BIG
)

# %% [markdown]
# ## Mean rows small dataset

# %%
if compare_dataframes(mean_rows_small_number['returned'], mean_rows_small_number_improved['returned']):
    compare_benchmarks(
        mean_rows_small_number,
        mean_rows_small_number_improved
    )
    compare_statistics_benchmarks(mean_rows_small_number, mean_rows_small_number_improved)
# Out:
# c:\Users\Stefo\Programming\Proper-Pandas\utilities\compare_benchmarks.py:68: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[row, col].set_xticklabels([textwrap.fill(label, width=10) for label in names])

# %% [markdown]
# ## Mean rows medium dataset

# %%
if compare_dataframes(mean_rows_medium_number['returned'], mean_rows_medium_number_improved['returned']):
    compare_benchmarks(
        mean_rows_medium_number,
        mean_rows_medium_number_improved
    )
    compare_statistics_benchmarks(mean_rows_medium_number, mean_rows_medium_number_improved)

# %% [markdown]
# ## Mean rows large dataset

# %%
if compare_dataframes(mean_rows_big_number['returned'], mean_rows_big_number_improved['returned']):
    compare_benchmarks(
        mean_rows_big_number,
        mean_rows_big_number_improved
    )
    compare_statistics_benchmarks(mean_rows_big_number, mean_rows_big_number_improved)

# %% [markdown]
# ## Now do the same thing but for columns

# %%
mean_cols_small_number = bench.benchmark(
    mean_columns,
    SMALL
)
mean_cols_small_number_improved = bench.benchmark(
    mean_columns_improved,
    SMALL
)


mean_cols_medium_number = bench.benchmark(
    mean_columns,
    MEDIUM
)
mean_cols_medium_number_improved = bench.benchmark(
    mean_columns_improved,
    MEDIUM
)


mean_cols_big_number = bench.benchmark(
    mean_columns,
    BIG
)
mean_cols_big_number_improved = bench.benchmark(
    mean_columns_improved,
    BIG
)

# %% [markdown]
# ## Mean columns small dataset

# %%
if compare_dataframes(mean_cols_small_number['returned'], mean_cols_small_number_improved['returned']):
    compare_benchmarks(
        mean_cols_small_number,
        mean_cols_small_number_improved
    )
    compare_statistics_benchmarks(mean_cols_small_number, mean_cols_small_number_improved)
# Out:
# c:\Users\Stefo\Programming\Proper-Pandas\utilities\compare_benchmarks.py:68: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[row, col].set_xticklabels([textwrap.fill(label, width=10) for label in names])

# %% [markdown]
# ## Mean columns medium dataset

# %%
if compare_dataframes(mean_cols_medium_number['returned'], mean_cols_medium_number_improved['returned']):
    compare_benchmarks(
        mean_cols_medium_number,
        mean_cols_medium_number_improved
    )
    compare_statistics_benchmarks(mean_cols_medium_number, mean_cols_medium_number_improved)

# %% [markdown]
# ## Mean columns large dataset

# %%
if compare_dataframes(mean_cols_big_number['returned'], mean_cols_big_number_improved['returned']):
    compare_benchmarks(
        mean_cols_big_number,
        mean_cols_big_number_improved
    )
    compare_statistics_benchmarks(mean_cols_big_number, mean_cols_big_number_improved)

# %% [markdown]
# ## Compare for median now beginning with rows

# %%
median_rows_small_number = bench.benchmark(
    median_rows,
    SMALL
)

median_rows_medium_number = bench.benchmark(
    median_rows,
    MEDIUM
)

median_rows_big_number = bench.benchmark(
    median_rows,
    BIG
) 

median_rows_small_number_improved = bench.benchmark(
    median_rows_improved,
    SMALL
)

median_rows_medium_number_improved = bench.benchmark(
    median_rows_improved,
    MEDIUM
)

median_rows_big_number_improved = bench.benchmark(
    median_rows_improved,
    BIG
)

# %%
if compare_dataframes(median_rows_small_number['returned'], median_rows_small_number['returned']):
    compare_benchmarks(
        median_rows_small_number,
        median_rows_small_number_improved
    )
    compare_statistics_benchmarks(median_rows_small_number, median_rows_small_number_improved)
# Out:
# c:\Users\Stefo\Programming\Proper-Pandas\utilities\compare_benchmarks.py:68: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[row, col].set_xticklabels([textwrap.fill(label, width=10) for label in names])

# %%
if compare_dataframes(median_rows_medium_number['returned'], median_rows_medium_number['returned']):
    compare_benchmarks(
        median_rows_medium_number,
        median_rows_medium_number_improved
    )
    compare_statistics_benchmarks(median_rows_medium_number, median_rows_medium_number_improved)

# %%
if compare_dataframes(median_rows_big_number['returned'], median_rows_big_number_improved['returned']):
    compare_benchmarks(
        median_rows_big_number,
        median_rows_big_number_improved
    )
    compare_statistics_benchmarks(median_rows_big_number, median_rows_big_number_improved)

# %% [markdown]
# ## Caulculate median for columns

# %%
median_cols_small_number = bench.benchmark(
    median_columns,
    SMALL
)

median_cols_medium_number = bench.benchmark(
    median_columns,
    MEDIUM
)

median_cols_big_number = bench.benchmark(
    median_columns,
    BIG
)

median_cols_small_number_improved = bench.benchmark(
    median_columns_improved,
    SMALL
)

median_cols_medium_number_improved = bench.benchmark(
    median_columns_improved,
    MEDIUM
)

median_cols_big_number_improved = bench.benchmark(
    median_columns_improved,
    BIG
)

# %%
if compare_dataframes(median_cols_small_number_improved['returned'], median_cols_small_number_improved['returned']):
    compare_benchmarks(
        median_cols_small_number,
        median_cols_small_number_improved
    )
    compare_statistics_benchmarks(median_cols_small_number, median_cols_small_number_improved)
# Out:
# c:\Users\Stefo\Programming\Proper-Pandas\utilities\compare_benchmarks.py:68: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[row, col].set_xticklabels([textwrap.fill(label, width=10) for label in names])

# %%
if compare_dataframes(median_cols_medium_number['returned'], median_cols_medium_number_improved['returned']):
    compare_benchmarks(
        median_cols_medium_number,
        median_cols_medium_number_improved
    )
    compare_statistics_benchmarks(median_cols_medium_number, median_cols_medium_number_improved)

# %%
if compare_dataframes(median_cols_big_number['returned'], median_cols_big_number_improved['returned']):
    compare_benchmarks(
        median_cols_big_number,
        median_cols_big_number_improved
    )
    compare_statistics_benchmarks(median_cols_big_number, median_cols_big_number_improved)
